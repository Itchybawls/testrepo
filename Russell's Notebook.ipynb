# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio" #

# %% [markdown]
# ![me.jpg](attachment:6b70d399-eab1-48ba-a816-e465c7071ab1.jpg)

# %% [markdown]
# **RUSSELL LEE PUGH**
# "I would like to work out of the Office of the Mayor @ Davita"

# %% [markdown]
# *I am interested in Data Science because its a way to improve my life. I am currently fighting Kidney Disease and am doing Home Hemodialysis. I am looking to set myself up for a stable career after I receive a kidney. I have been waiting for 7 years and am now top priority! This should be my year.*

# %% [markdown]
# ### We will be dividing 16oz by quarters ###

# %%
num=16
result = num/.25
print(result)
# Out:
# 64.0

# %% [markdown]
# -  Need Certification
# 1. Pass Tests
# 2. <div class="alert alert-block alert-danger">
# <b>Get Kidney and heal up</b>
# </div>
# &#963925 Get job with Davita
